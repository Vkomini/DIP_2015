# %% [markdown]
# # Digital Image Processing<br> Problem 7<br> Felix Neutatz

# %% [markdown]
# ##Transform image compression

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from functools import partial
from scipy.fftpack import dct

# %%
def plotGreyImage(imageToPlot, title):
    plt.imshow(imageToPlot, cmap='gray') #Greys_r
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
imageName = 'lenna.tif'
img = mpimg.imread(imageName)
plotGreyImage(img, "original image")
